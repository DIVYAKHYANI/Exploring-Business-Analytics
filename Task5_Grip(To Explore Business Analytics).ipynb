# %% [markdown]
# # Task5 (DATA SCIENCE AND ANALYTICS INTERNSHIP) -DIVYA KHYANI

# %% [markdown]
# # Aim : To Explore Business Analytics

# %% [markdown]
# # Detailed Problem Statement:

# %% [markdown]
# This task aims to perform ‘Exploratory Data Analysis’ on the provided dataset ‘SampleSuperstore’
# Considering myself as business owner of the retail firm and I want to see how my company is performing.
# I am interested in finding the weak areas where I can work to make more profit.
# What all business problems I can derive by looking into the data?

# %% [markdown]
# # Importing the Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Importing and Reading the Dataset "SampleSuperstore"

# %%
df = pd.read_csv('SampleSuperstore.csv')

# %% [markdown]
# # The first 5 rows

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [markdown]
# # The last 5 rows

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %% [markdown]
# # Desciption of Dataset

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# # Total number of Rows and Columns

# %%
df.shape
# Out:
# (9994, 13)

# %% [markdown]
# There are 9994 Rows and 13 columns in this Dataset

# %% [markdown]
# # Columns of the Given Dataset

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# # The Summary of the Database is as follows:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# Counting the number of numerical(int and float) datatype columns, there are 5 in number as seen above i.e; Postal Code, Sales,
# Quantity, Discount, and Profit.

# %% [markdown]
# # Checking for Duplicate Enteries (if any)

# %%
duplicate=df.duplicated()
print(duplicate.sum())
df[duplicate]
# Out:
# 17
#            Ship Mode      Segment        Country           City         State  \
# 950   Standard Class  Home Office  United States   Philadelphia  Pennsylvania
# 3406  Standard Class  Home Office  United States       Columbus          Ohio
# 3670  Standard Class     Consumer  United States          Salem        Oregon
# 4117  Standard Class     Consumer  United States    Los Angeles    California
# 4553  Standard Class     Consumer  United States  San Francisco    California
# 5905        Same Day  Home Office  United States  San Francisco    California
# 6146  Standard Class    Corporate  United States  San Francisco    California
# 6334  Standard Class     Consumer  United States  New York City      New York
# 6357  Standard Class    Corporate  United States        Seattle    Washington
# 7608  Standard Class     Consumer  United States  San Francisco    California
# 7735  Standard Class    Corporate  United States        Seattle    Washington
# ...

# %% [markdown]
# There are 17 duplicate records in the data!
# In order to make these records distinct we will have DROP these duplicate records.

# %% [markdown]
# # Dropping Duplicate Records

# %%
df.drop_duplicates(inplace = True)

# %% [markdown]
# # To reassure let's check for the duplicates:

# %%
dpl = df.duplicated()
dpl.sum()
# Out:
# 0

# %% [markdown]
# # Checking for Null Values in the dataset

# %%
df.isnull()
# Out:
#       Ship Mode  Segment  Country   City  State  Postal Code  Region  \
# 0         False    False    False  False  False        False   False
# 1         False    False    False  False  False        False   False
# 2         False    False    False  False  False        False   False
# 3         False    False    False  False  False        False   False
# 4         False    False    False  False  False        False   False
# ...         ...      ...      ...    ...    ...          ...     ...
# 9989      False    False    False  False  False        False   False
# 9990      False    False    False  False  False        False   False
# 9991      False    False    False  False  False        False   False
# 9992      False    False    False  False  False        False   False
# 9993      False    False    False  False  False        False   False
#
#       Category  Sub-Category  Sales  Quantity  Discount  Profit
# 0        False         False  False     False     False   False
# ...

# %% [markdown]
# No null values in the dataset

# %% [markdown]
# # Checking for Unique Values

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# Postal Cards is an unneccessary column.Let's drop it

# %%
col=['Postal Code']
df_new=df.drop(columns=col, axis=1)

# %% [markdown]
# Checking if it is dropped or not

# %%
df_new.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Region',
#        'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# # Visualization of the Dataset

# %% [raw]
# HISTOGRAM

# %%
df_new.hist(figsize=(10, 10), bins=50)
plt.show()

# %% [raw]
# Pairplots

# %%
sns.set()
sns.pairplot(df_new, height = 2.5)
plt.show()

# %% [markdown]
# From the above pairplot we can observe that the Sales, Quantity,Discount, and Profit is considered being the numerical valued columns!

# %% [raw]
# Correlation

# %%
df_new.corr()
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200722 -0.028311  0.479067
# Quantity  0.200722  1.000000  0.008678  0.066211
# Discount -0.028311  0.008678  1.000000 -0.219662
# Profit    0.479067  0.066211 -0.219662  1.000000

# %% [raw]
# Heatmap

# %%
corr = df_new.corr()
sns.heatmap(corr,annot=True)

# %% [markdown]
# # Count of Orders :

# %% [raw]
# For Each Ship-Mode

# %%
sns.countplot(df_new['Ship Mode'])
plt.show()

# %% [raw]
# For Each Segment

# %%
sns.countplot(df_new['Segment'])
plt.show()

# %% [raw]
# For Each Region

# %%
sns.countplot(df_new['Region'])
plt.show()

# %% [raw]
# For Each Sub-Category

# %%
sns.countplot(df_new['Category'])
plt.show()

# %% [raw]
#  for Each subcategory

# %%
grouped = df_new.groupby(['Category','Sub-Category'])
grouped.size()
subcategory_table = pd.crosstab(index=df_new["Category"], 
                          columns=df_new["Sub-Category"])

subcategory_table
# Out:
# Sub-Category     Accessories  Appliances  Art  Binders  Bookcases  Chairs  \
# Category
# Furniture                  0           0    0        0        228     615
# Office Supplies            0         466  795     1522          0       0
# Technology               775           0    0        0          0       0
#
# Sub-Category     Copiers  Envelopes  Fasteners  Furnishings  Labels  Machines  \
# Category
# Furniture              0          0          0          956       0         0
# Office Supplies        0        254        217            0     363         0
# Technology            68          0          0            0       0       115
#
# Sub-Category     Paper  Phones  Storage  Supplies  Tables
# Category
# Furniture            0       0        0         0     319
# Office Supplies   1359       0      846       190       0
# Technology           0     889        0         0       0

# %%
subcategory_table.plot(kind="bar", figsize=(8,8), stacked=True)

# %% [raw]
#  For each State

# %%
df_new['State'].value_counts().plot(kind = 'bar', figsize=(20,10))

# %% [markdown]
# # Plotting the top 15 cities with Most number of orders

# %%
df_new['City'].value_counts()
# Out:
# New York City    914
# Los Angeles      746
# Philadelphia     536
# San Francisco    506
# Seattle          424
#                 ...
# Springdale         1
# Linden             1
# Abilene            1
# Elyria             1
# Rogers             1
# Name: City, Length: 531, dtype: int64

# %%
df_new['City'].value_counts().head(15).plot(kind = 'bar', figsize=(20,10))

# %% [markdown]
# # Plotting the last 15 cities with least number of Orders

# %%
df_new['City'].value_counts().tail(15).plot(kind = 'bar', figsize=(20,10))

# %% [markdown]
# # Discussion over Quantities

# %% [raw]
# Quantities ordered by ship-modes

# %%
df.shipmode = df.groupby('Ship Mode')['Quantity'].sum().reset_index()
print(df.shipmode)
# Out:
#         Ship Mode  Quantity
# 0     First Class      5690
# 1        Same Day      1956
# 2    Second Class      7418
# 3  Standard Class     22756

# %%
shipmode_quantity=pd.DataFrame(df.groupby('Ship Mode').sum()['Quantity'])
labels=df.shipmode['Ship Mode'].unique()
plt.figure(figsize=(5,5))
plt.pie(df.shipmode['Quantity'], labels=shipmode_quantity.index, autopct='%1.1f%%', explode=(0.02, 0.02, 0.02, 0.02),)
plt.title('Quantities ordered by Ship Modes', size=15)
# Out:
# Text(0.5, 1.0, 'Quantities ordered by Ship Modes')

# %% [markdown]
# The Highest portion is covered by Standard Class Ship Mode as seen above!

# %% [raw]
# Quantities ordered by Segment

# %%
df.segment = df.groupby('Segment')['Quantity'].sum().reset_index()
print(df.segment)
# Out:
#        Segment  Quantity
# 0     Consumer     19497
# 1    Corporate     11591
# 2  Home Office      6732

# %%
segment_quantity=pd.DataFrame(df.groupby('Segment').sum()['Quantity'])
labels=df.segment['Segment'].unique()
plt.figure(figsize=(5,5))
plt.pie(df.segment['Quantity'], labels=segment_quantity.index, autopct='%1.1f%%', explode=(0.02, 0.02, 0.02),)
plt.title('Quantities ordered by Segment', size=15)
# Out:
# Text(0.5, 1.0, 'Quantities ordered by Segment')

# %% [markdown]
# The Highest Proportion is covered by Consumer Segment and the lowest Proportion is covered by Home Office as seen above!

# %% [raw]
# Quantities ordered by Region

# %%
df.region = df.groupby('Region')['Quantity'].sum().reset_index()
print(df.region)
# Out:
#     Region  Quantity
# 0  Central      8768
# 1     East     10609
# 2    South      6209
# 3     West     12234
# C:\Users\divya khyani\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
region_quantity=pd.DataFrame(df.groupby('Region').sum()['Quantity'])
labels=df.region['Region'].unique()
plt.figure(figsize=(5,5))
plt.pie(df.region['Quantity'], labels=region_quantity.index, autopct='%1.1f%%', explode=(0.02, 0.02, 0.02, 0.02),)
plt.title('Quantities ordered by Region', size=15)
# Out:
# Text(0.5, 1.0, 'Quantities ordered by Region')

# %% [markdown]
# The highest proportion of quantities are ordered by West region and the lowest proportion of quantities are ordered by South region.

# %% [raw]
# Quantities ordered by Categories

# %%
df.category = df.groupby('Category')['Quantity'].sum().reset_index()
print(df.category)
# Out:
#           Category  Quantity
# 0        Furniture      8020
# 1  Office Supplies     22861
# 2       Technology      6939
# C:\Users\divya khyani\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
category_quantity=pd.DataFrame(df.groupby('Category').sum()['Quantity'])
labels=df.category['Category'].unique()
plt.figure(figsize=(5,5))
plt.pie(df.category['Quantity'], labels=category_quantity.index, autopct='%1.1f%%', explode=(0.02, 0.02, 0.02),)
plt.title('Quantities ordered by Categories', size=15)
# Out:
# Text(0.5, 1.0, 'Quantities ordered by Categories')

# %% [markdown]
# The Highest proportion is covered by Office Supplies and lowest proportion is covered by Technology

# %% [raw]
# Quantities covered by Sub-Category

# %%
df.subcategory = df.groupby('Sub-Category')['Quantity'].sum().reset_index()
print(df.subcategory)
# Out:
#    Sub-Category  Quantity
# 0   Accessories      2976
# 1    Appliances      1729
# 2           Art      2996
# 3       Binders      5971
# 4     Bookcases       868
# 5        Chairs      2351
# 6       Copiers       234
# 7     Envelopes       906
# 8     Fasteners       914
# 9   Furnishings      3560
# 10       Labels      1396
# 11     Machines       440
# 12        Paper      5144
# 13       Phones      3289
# 14      Storage      3158
# 15     Supplies       647
# 16       Tables      1241
# C:\Users\divya khyani\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
subcategory_quantity=pd.DataFrame(df.groupby('Sub-Category').sum()['Quantity'])
labels=df.subcategory['Sub-Category'].unique()
plt.figure(figsize=(12,12))
plt.pie(df.subcategory['Quantity'], labels=subcategory_quantity.index,)
plt.title('Quantities ordered by Sub-Categories', size=15)
# Out:
# Text(0.5, 1.0, 'Quantities ordered by Sub-Categories')

# %% [markdown]
# The Highest and Lowest Proportion is covered by Binders and Copiers respectively.

# %% [raw]
# Quantities ordered by States

# %%
states_quantity=df.groupby('State')['Quantity'].sum().reset_index().sort_values(by='Quantity', ascending=False)

# %% [markdown]
# # Top 10 Cities in terms of Quantities:

# %%
top10_states_quantity=states_quantity.head(10)
sns.catplot('State', 'Quantity', data=top10_states_quantity, kind='bar', aspect=2, height=8, palette="pink")

# %% [markdown]
# California has ordered the highest number of goods and Michigan has ordered the lowest number of goods

# %% [markdown]
# # Bottom 10 states in terms of Quantities

# %%
bottom10_states_quantity=states_quantity.tail(10)
sns.catplot('State', 'Quantity', data=bottom10_states_quantity, kind='bar', aspect=2, height=8, palette="pink")

# %% [markdown]
# Kansas has ordered the highest number of goods and Wyoming has ordered the lowest number of goods.

# %% [raw]
# Quantities ordered by Cities

# %%
cities_quantity=df.groupby('City')['Quantity'].sum().reset_index().sort_values(by='Quantity', ascending=False)

# %% [markdown]
# # Top 20 cities in terms of Quantity

# %%
top20_cities_quantity=cities_quantity.head(20)
sns.catplot('City', 'Quantity', data=top20_cities_quantity, kind='bar', aspect=2, height=8, palette="pink")

# %% [markdown]
# Newyork has ordered the highest number of orders and Long Beach has lowest number of orders.

# %% [markdown]
# # Bottom 20 cities in terms of Quantity

# %%
bottom20_cities_quantity=cities_quantity.tail(20)
sns.catplot('City', 'Quantity', data=bottom20_cities_quantity, kind='bar', aspect=2, height=8, palette="pink")

# %% [markdown]
# Kissimee has ordered the highest number of orders and Elyria has ordered the lowest number of orders.

# %% [markdown]
# # Discussion over Sales

# %% [raw]
# Ship-Mode wise sales

# %%
df.shipmodesales = df.groupby('Ship Mode')['Sales'].sum().reset_index()
print(df.shipmodesales)
# Out:
#         Ship Mode         Sales
# 0     First Class  3.513805e+05
# 1        Same Day  1.283217e+05
# 2    Second Class  4.591770e+05
# 3  Standard Class  1.357316e+06

# %%
shipmode_sales=pd.DataFrame(df.groupby('Ship Mode').sum()['Sales'])
labels=df.shipmodesales['Ship Mode'].unique()
plt.figure(figsize=(5,5))
plt.pie(df.shipmodesales['Sales'], labels=shipmode_sales.index, autopct='%.2f', explode=(0.02, 0.02, 0.02, 0.02), radius=1.2)
centre_circle=plt.Circle((0,0), 0.90, fc='white')
fig=plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title('Sales ordered by Ship Modes', size=15)
# Out:
# Text(0.5, 1.0, 'Sales ordered by Ship Modes')

# %% [markdown]
# "Same Day" shipment mode accounted for the lowest sales and "Standard Class" shipment mode accounted for the highest sales.

# %% [raw]
# Segment wise Sales

# %%
df.segmentsales = df.groupby('Segment')['Sales'].sum().reset_index()
print(df.segmentsales)
# Out:
#        Segment         Sales
# 0     Consumer  1.160833e+06
# 1    Corporate  7.060701e+05
# 2  Home Office  4.292927e+05

# %%
segment_sales=pd.DataFrame(df.groupby('Segment').sum()['Sales'])
labels=df.segmentsales['Segment'].unique()
plt.figure(figsize=(6,6))
plt.pie(df.segmentsales['Sales'], labels=segment_sales.index, autopct='%.2f', explode=(0.02, 0.02, 0.02), radius=1.2)
centre_circle=plt.Circle((0,0), 0.90, fc='white')
fig=plt.gcf()
fig.gca().add_artist(centre_circle)

# %% [markdown]
# Consumer Segment accounted for the highest sales and Home Office accounted for the lowest sales

# %% [raw]
# Region wise Sales

# %%
df.regionsales = df.groupby('Region')['Sales'].sum().reset_index()
print(df.regionsales)
# Out:
#     Region        Sales
# 0  Central  500782.8528
# 1     East  678435.1960
# 2    South  391721.9050
# 3     West  725255.6365
# C:\Users\divya khyani\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
region_sales=pd.DataFrame(df.groupby('Region').sum()['Sales'])
labels=df.regionsales['Region'].unique()
plt.figure(figsize=(5,5))
plt.pie(df.regionsales['Sales'], labels=region_sales.index, autopct='%.2f', explode=(0.02, 0.02, 0.02, 0.02), radius=1.2)
centre_circle=plt.Circle((0,0), 0.90, fc='white')
fig=plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title('Sales ordered by Regions', size=15)
# Out:
# Text(0.5, 1.0, 'Sales ordered by Regions')

# %% [markdown]
# West Region accounted for the highest sales and South region accounted for the lowest sales

# %% [raw]
# Category-wise Sales

# %%
df.categorysales = df.groupby('Category')['Sales'].sum().reset_index()
print(df.categorysales)
# Out:
#           Category        Sales
# 0        Furniture  741306.3133
# 1  Office Supplies  718735.2440
# 2       Technology  836154.0330
# C:\Users\divya khyani\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
category_sales=pd.DataFrame(df.groupby('Category').sum()['Sales'])
labels=df.categorysales['Category'].unique()
plt.figure(figsize=(5,5))
plt.pie(df.categorysales['Sales'], labels=category_sales.index, autopct='%.2f', explode=(0.02, 0.02, 0.02), radius=1.2)
centre_circle=plt.Circle((0,0), 0.90, fc='white')
fig=plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title('Sales ordered by Categories', size=15)
# Out:
# Text(0.5, 1.0, 'Sales ordered by Categories')

# %% [markdown]
# Technology accounted for the highest sales and Office Supplies for the lowest sales

# %% [raw]
# Sub Category Wise sales

# %%
df.subcategorysales = df.groupby('Sub-Category')['Sales'].sum().reset_index()
print(df.subcategorysales)
# Out:
#    Sub-Category        Sales
# 0   Accessories  167380.3180
# 1    Appliances  107532.1610
# 2           Art   27107.0320
# 3       Binders  203409.1690
# 4     Bookcases  114879.9963
# 5        Chairs  327777.7610
# 6       Copiers  149528.0300
# 7     Envelopes   16476.4020
# 8     Fasteners    3024.2800
# 9   Furnishings   91683.0240
# 10       Labels   12444.9120
# 11     Machines  189238.6310
# 12        Paper   78224.1420
# 13       Phones  330007.0540
# 14      Storage  223843.6080
# 15     Supplies   46673.5380
# 16       Tables  206965.5320
# C:\Users\divya khyani\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
subcategory_sales=pd.DataFrame(df.groupby('Sub-Category').sum()['Sales'])
labels=df.subcategorysales['Sub-Category'].unique()
plt.figure(figsize=(15,15))
plt.pie(df.subcategorysales['Sales'], labels=subcategory_sales.index, autopct='%.2f', radius=1.2)
centre_circle=plt.Circle((0,0), 0.90, fc='white')
fig=plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title('Sales ordered by Sub-Categories', size=15)
# Out:
# Text(0.5, 1.0, 'Sales ordered by Sub-Categories')

# %% [markdown]
# Phones have accounted for the highest proportion of sales whwereas Fasteners accounted for the Lowest

# %% [raw]
# Sales Ordered by States

# %%
states_sales=df.groupby('State')['Sales'].sum().reset_index().sort_values(by='Sales', ascending=False)

# %% [markdown]
# # Top 10 states considering sales as a factor

# %%
top10_states_sales=states_sales.head(10)
sns.catplot('State', 'Sales', data=top10_states_sales, kind='bar', aspect=2, height=4, palette="pink")

# %% [markdown]
# # Bottom 10 states considering sales as a factor

# %%
bottom10_states_sales=states_sales.tail(10)
sns.catplot('State', 'Sales', data=bottom10_states_sales, kind='bar', aspect=2, height=4, palette="pink")

# %% [raw]
# Sales ordered by Cities

# %%
cities_sales=df.groupby('City')['Sales'].sum().reset_index().sort_values(by='Sales', ascending=False)

# %% [markdown]
# # Top 10 cities considering sales as a factor

# %%
top10_cities_sales=cities_sales.head(10)
sns.catplot('City', 'Sales', data=top10_cities_sales, kind='bar', aspect=3, height=8, palette="pink")

# %% [markdown]
# # Bottom 10 cities considering sales as a factor

# %%
bottom10_cities_sales=cities_sales.tail(10)
sns.catplot('City', 'Sales', data=bottom10_cities_sales, kind='bar', aspect=3, height=8, palette="pink")

# %% [markdown]
# # Discussion over Discounts

# %% [raw]
# Discount across Ship Modes

# %%
df.shipmodedisc = df.groupby('Ship Mode')['Discount'].agg(np.mean).reset_index().sort_values(by='Discount', ascending=False)
print(df.shipmodedisc)
# Out:
#         Ship Mode  Discount
# 0     First Class  0.164587
# 3  Standard Class  0.160222
# 1        Same Day  0.152675
# 2    Second Class  0.138626
# C:\Users\divya khyani\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
(markerline, stemlines, baseline) = plt.stem(df.shipmodedisc['Ship Mode'],
                                             df.shipmodedisc['Discount'], use_line_collection=True)
plt.setp(markerline, marker='*', markersize=15,
         markeredgewidth=2, color='purple')
plt.setp(stemlines, color='purple')
plt.setp(baseline, visible=False)

plt.tick_params(labelsize=12)
plt.xlabel('Ship Mode', size=12)
plt.ylabel('Discount', size=12)
plt.ylim(bottom=0)

plt.show()

# %% [markdown]
# Most Discounted shipmode-First Class and
# Least Discounted shipmode-Second Class

# %% [raw]
# Discount across Segments

# %%
df.segmentdisc = df.groupby('Segment')['Discount'].agg(np.mean).reset_index().sort_values(by='Discount', ascending=False)
print(df.segmentdisc)
# Out:
#        Segment  Discount
# 0     Consumer  0.158308
# 1    Corporate  0.158159
# 2  Home Office  0.147178
# C:\Users\divya khyani\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
(markerline, stemlines, baseline) = plt.stem(df.segmentdisc['Segment'],
                                             df.segmentdisc['Discount'], use_line_collection=True)
plt.setp(markerline, marker='*', markersize=15,
         markeredgewidth=2, color='red')
plt.setp(stemlines, color='red')
plt.setp(baseline, visible=False)

plt.tick_params(labelsize=12)
plt.xlabel('Segment', size=12)
plt.ylabel('Discount', size=12)
plt.ylim(bottom=0)

plt.show()

# %% [markdown]
# There is no significant difference observed among the segments

# %% [raw]
# Discount Across Regions

# %%
df.regiondisc = df.groupby('Region')['Discount'].agg(np.mean).reset_index().sort_values(by='Discount', ascending=False)
print(df.regiondisc)
# Out:
#     Region  Discount
# 0  Central  0.240250
# 2    South  0.147253
# 1     East  0.145343
# 3     West  0.109615
# C:\Users\divya khyani\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
(markerline, stemlines, baseline) = plt.stem(df.regiondisc['Region'],
                                             df.regiondisc['Discount'], use_line_collection=True)
plt.setp(markerline, marker='*', markersize=15,
         markeredgewidth=2, color='gold')
plt.setp(stemlines, color='gold')
plt.setp(baseline, visible=False)

plt.tick_params(labelsize=12)
plt.xlabel('Region', size=12)
plt.ylabel('Discount', size=12)
plt.ylim(bottom=0)

plt.show()

# %% [markdown]
# Highest Discounted Region- Central and Lowest Discounted Region- West

# %% [raw]
# Discount across Categories

# %%
df.categorydisc = df.groupby('Category')['Discount'].agg(np.mean).reset_index().sort_values(by='Discount', ascending=False)
print(df.categorydisc)
# Out:
#           Category  Discount
# 0        Furniture  0.174027
# 1  Office Supplies  0.157385
# 2       Technology  0.132323
# C:\Users\divya khyani\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
(markerline, stemlines, baseline) = plt.stem(df.categorydisc['Category'],
                                             df.categorydisc['Discount'], use_line_collection=True)
plt.setp(markerline, marker='*', markersize=15,
         markeredgewidth=2, color='green')
plt.setp(stemlines, color='green')
plt.setp(baseline, visible=False)

plt.tick_params(labelsize=12)
plt.xlabel('Category', size=12)
plt.ylabel('Discount', size=12)
plt.ylim(bottom=0)

plt.show()

# %% [markdown]
# Most Discounted Category: Furniture and Least Discounted Category: Technology

# %% [raw]
# Discount across Sub-categories

# %%
df.subcategorydisc = df.groupby('Sub-Category')['Discount'].agg(np.mean).reset_index().sort_values(by='Discount', ascending=False)
print(df.subcategorydisc)
# Out:
#    Sub-Category  Discount
# 3       Binders  0.372011
# 11     Machines  0.306087
# 16       Tables  0.261285
# 4     Bookcases  0.211140
# 5        Chairs  0.170244
# 1    Appliances  0.166524
# 6       Copiers  0.161765
# 13       Phones  0.154556
# 9   Furnishings  0.138494
# 8     Fasteners  0.082028
# 7     Envelopes  0.080315
# 0   Accessories  0.078452
# 15     Supplies  0.076842
# 2           Art  0.074969
# 12        Paper  0.074908
# 14      Storage  0.074704
# 10       Labels  0.068871
# C:\Users\divya khyani\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
plt.figure(figsize=(15,15))
(markerline, stemlines, baseline) = plt.stem(df.subcategorydisc['Sub-Category'],
                                             df.subcategorydisc['Discount'], use_line_collection=True)
plt.setp(markerline, marker='*', markersize=15,
         markeredgewidth=2, color='blue')
plt.setp(stemlines, color='blue')
plt.setp(baseline, visible=False)

plt.tick_params(labelsize=12)
plt.xlabel('Sub-Category', size=12)
plt.ylabel('Discount', size=12)
plt.ylim(bottom=0)

plt.show()

# %% [markdown]
# Most Discounted Sub-category- Blinders and Lease Discounted Sub-category- Labels

# %% [raw]
# Discount across States

# %%
df.statedisc = df.groupby('State')['Discount'].agg(np.mean).reset_index().sort_values(by='Discount', ascending=False)
# Out:
# C:\Users\divya khyani\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Top 10 States with high Discounts

# %%
top10_states_disc=df.statedisc.head(10)
print(top10_states_disc)
# Out:
#              State  Discount
# 11        Illinois  0.389206
# 41           Texas  0.370539
# 36    Pennsylvania  0.328840
# 33            Ohio  0.325000
# 4         Colorado  0.316484
# 1          Arizona  0.303571
# 8          Florida  0.299347
# 40       Tennessee  0.291257
# 35          Oregon  0.289431
# 31  North Carolina  0.283534

# %%
plt.figure(figsize=(25,5))
(markerline, stemlines, baseline) = plt.stem(top10_states_disc['State'],
                                             top10_states_disc['Discount'], use_line_collection=True)
plt.setp(markerline, marker='*', markersize=15,
         markeredgewidth=2, color='black')
plt.setp(stemlines, color='black')
plt.setp(baseline, visible=False)

plt.tick_params(labelsize=12)
plt.xlabel('State', size=12)
plt.ylabel('Discount', size=12)
plt.ylim(bottom=0)

plt.show()

# %% [markdown]
# State which was offered the Highest Discount- Illinois

# %% [raw]
# Discount across Cities

# %%
df.citydisc = df.groupby('City')['Discount'].agg(np.mean).reset_index().sort_values(by='Discount', ascending=False)
# Out:
# C:\Users\divya khyani\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Top 20 cities with High Discounts

# %%
top20_cities_disc=df.citydisc.head(20)
print(top20_cities_disc)
# Out:
#                City  Discount
# 1           Abilene  0.800000
# 117       Deer Park  0.800000
# 417      Romeoville  0.800000
# 305   Missouri City  0.800000
# 140          Elyria  0.700000
# 370       Pensacola  0.700000
# 354    Ormond Beach  0.700000
# 259       Littleton  0.700000
# 493           Tyler  0.640000
# 55            Bryan  0.616667
# 355          Oswego  0.600000
# 71        Champaign  0.600000
# 484     Tinley Park  0.600000
# 182      Grove City  0.550000
# 284           Mason  0.533333
# 108  Cuyahoga Falls  0.533333
# 294        Mesquite  0.520000
# 502            Waco  0.520000
# 392          Pueblo  0.512500
# 413        Rockford  0.509091

# %%
plt.figure(figsize=(25,5))
(markerline, stemlines, baseline) = plt.stem(top20_cities_disc['City'],
                                             top20_cities_disc['Discount'], use_line_collection=True)
plt.setp(markerline, marker='*', markersize=15,
         markeredgewidth=2, color='pink')
plt.setp(stemlines, color='pink')
plt.setp(baseline, visible=False)

plt.tick_params(labelsize=12)
plt.xlabel('City', size=12)
plt.ylabel('Discount', size=12)
plt.ylim(bottom=0)

plt.show()

# %% [markdown]
# Cities offered with Highest Discount- Abilene, Deer Park, Romeoville and Missouri City.

# %% [markdown]
# # Discussion over Profits

# %% [raw]
# Ship-mode wise Profits

# %%
shipmode_profit=df.groupby('Ship Mode')['Profit'].sum().reset_index().sort_values(by='Profit', ascending=False)

# %%
sns.catplot('Ship Mode', 'Profit', data=shipmode_profit, kind='bar', aspect=2, height=4, palette="rainbow")

# %% [markdown]
# As seen "Standard Class" has generated the highest profits and "Same Day" has generated the lowest profits.

# %% [raw]
# Segment wise Profits

# %%
segment_profit=df.groupby('Segment')['Profit'].sum().reset_index().sort_values(by='Profit', ascending=False)

# %%
sns.catplot('Segment', 'Profit', data=segment_profit, kind='bar', aspect=2, height=4, palette="rainbow")

# %% [markdown]
#  As seen "Consumer" has received the highest profits and "Home Office" has received the lowest profits.

# %% [raw]
# Region wise Profits

# %%
region_profit=df.groupby('Region')['Profit'].sum().reset_index().sort_values(by='Profit', ascending=False)

# %%
sns.catplot('Region', 'Profit', data=region_profit, kind='bar', aspect=2, height=4, palette="rainbow")

# %% [markdown]
# West Region has received highest profits and Cental Region has received the lowest profits.

# %% [raw]
# Category wise Profits

# %%
category_profit=df.groupby('Category')['Profit'].sum().reset_index().sort_values(by='Profit', ascending=False)

# %%
sns.catplot('Category', 'Profit', data=category_profit, kind='bar', aspect=2, height=4, palette="rainbow")

# %% [markdown]
# Clearly Technology has been most profitable and Furniture least!

# %% [raw]
# Sub-Category wise Profits

# %%
subcategory_profit=df.groupby('Sub-Category')['Profit'].sum().reset_index().sort_values(by='Profit', ascending=False)

# %%
sns.catplot('Sub-Category', 'Profit', data=subcategory_profit, kind='bar', aspect=1, height=18, palette="rainbow")

# %% [markdown]
# The Most-Profitable sub-category-Copiers

# %% [markdown]
# The Least Profitable sub-category-Machines

# %% [markdown]
# The sub-category with Highest loss-Tables

# %% [raw]
# State wise Profits

# %%
states_profit=df.groupby('State')['Profit'].sum().reset_index().sort_values(by='Profit', ascending=False)

# %% [markdown]
# # Top 10 Profitable States

# %%
top10_states_profit=states_profit.head(10)
sns.catplot('State', 'Profit', data=top10_states_profit, kind='bar', aspect=2, height=5, palette="rainbow")

# %% [markdown]
# California is the most profitable state

# %% [markdown]
# # Bottom 10 Profitable States

# %%
bottom5_states_profit=states_profit.tail(5)
sns.catplot('State', 'Profit', data=bottom5_states_profit, kind='bar', aspect=2, height=4, palette="rainbow")

# %% [markdown]
# Texas is the state with Highest loss

# %% [raw]
# City Wise Profits

# %%
cities_profit=df.groupby('City')['Profit'].sum().reset_index().sort_values(by='Profit', ascending=False)

# %% [markdown]
# # Top 10 Profitable Cities

# %%
top10_cities_profit=cities_profit.head(10)
sns.catplot('City', 'Profit', data=top10_cities_profit, kind='bar', aspect=2, height=8, palette="rainbow")

# %% [markdown]
# New York City is the most profitable City

# %% [markdown]
# # Bottom 10 Profitable Cities

# %%
bottom10_cities_profit=cities_profit.tail(10)
sns.catplot('City', 'Profit', data=bottom10_cities_profit, kind='bar', aspect=2, height=8, palette="rainbow")

# %% [markdown]
# Philadelphia is least profitable city with huge losses.

# %% [markdown]
# # -------------------------------------------------END-------------------------------------------------------
